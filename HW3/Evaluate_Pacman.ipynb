# %%
import gym
import gym.spaces
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from collections import namedtuple, deque
import itertools
import sys
import random
from tensorflow.python.tools import inspect_checkpoint as chkp
#SELECT GPU
os.environ["CUDA_VISIBLE_DEVICES"]= "2"

# %% [markdown]
# #### Preprocess function from tutorial

# %%
mspacman_color = 210 + 164 + 74
def preprocess_observation(obs):
    img = obs[1:176:2, ::2] # crop and downsize
    img = img.sum(axis=2) # to greyscale
    img[img==mspacman_color] = 0 # Improve contrast
    img = (img // 3 - 128).astype(np.int8) # normalize from -128 to 127
    return img.reshape(88, 80)

    return np.reshape(image.astype(np.float).ravel(), [80,80])

env = gym.envs.make("MsPacman-v0")

# %%
def make_epsilon_greedy_policy(q_predictions, q_X, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function approximator and epsilon.
    Args:
        q_predictions: The tf node that gets q predictions for each action given a state
        q_X: The tf node that is the input placeholder for the network (state)
        nA: Number of actions in the environment.
    Returns:
        A function that takes the (sess, observation, epsilon) as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    """
    def policy_fn(sess, observation, epsilon):
        A = np.ones(nA, dtype=float) * epsilon / nA
        #q_values = estimator.predict(sess, np.expand_dims(observation, 0))[0]
        #Get q values for the various actions
        q_values = sess.run(q_predictions, feed_dict={q_X : np.expand_dims(observation,0)})[0]
        best_action = np.argmax(q_values)
        #Use the linearly decreasing explore factor for the suboptimal actions, and 1-epsilon for optimal
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
num_games = 1000
experiment_dir = os.path.relpath("./pacman_experiments")
checkpoint_dir = os.path.join(experiment_dir, "checkpoints")
checkpoint_path = os.path.join(checkpoint_dir, "model")
poss_actions = list(range(9))
learning_rate = 2e-4

# %%
def build_model(scope):
        """
        Function to build a tensorflow graph and return its components
        """
        #This folder will store the summaries folder.
        summaries_dir = "./pacman_summaries"
        
        with tf.variable_scope(scope):
            # Placeholders for our input
        
            X_pl = tf.placeholder(shape=[None, 88, 80,4], dtype=tf.float32, name="X")
            # The TD target value
            y_pl = tf.placeholder(shape=[None], dtype=tf.float32, name="y")
            # Index of selected action
            actions_pl = tf.placeholder(shape=[None], dtype=tf.int32, name="actions")
            
            X = X_pl
            batch_size = tf.shape(X_pl)[0]
            
            # Three convolutional layers
            conv1 = tf.contrib.layers.conv2d(
                X, 32, 8, 2, activation_fn=tf.nn.relu)
            conv2 = tf.contrib.layers.conv2d(
                conv1, 64, 4, 2, activation_fn=tf.nn.relu)
            conv3 = tf.contrib.layers.conv2d(
                conv2, 64, 3, 1, activation_fn=tf.nn.relu)
            # Fully connected layers - 1 hiden layer and an output layer.
            flattened = tf.contrib.layers.flatten(conv3)
            fc1 = tf.contrib.layers.fully_connected(flattened, 512)
            predictions = tf.contrib.layers.fully_connected(fc1, len(poss_actions), activation_fn=None)
            # Get the predictions for the chosen actions only
#             gather_indices = tf.range(batch_size) * tf.shape(predictions)[1] + actions_pl
#             action_predictions = tf.gather(tf.reshape(predictions, [-1]), gather_indices)
            
            #Only take Q for the action we take (multiply with one hot vector)
            action_one_hot = tf.one_hot(actions_pl, len(poss_actions), 1.0, 0.0, name='action_one_hot')
            action_predictions = tf.reduce_sum(tf.multiply(predictions, action_one_hot), axis=1)
            
            # Calculate the loss
            losses = tf.squared_difference(y_pl, action_predictions)
            loss = tf.reduce_mean(losses)
            # Adam optimizer to reduce MSE
            optimizer = tf.train.AdamOptimizer(learning_rate)#, 0.99, 0.0, 1e-6)
            train_op = optimizer.minimize(loss, global_step=tf.contrib.framework.get_global_step())
            
            #Summaries for tensorboard
            summaries = tf.summary.merge([
            tf.summary.scalar("loss", loss),
            tf.summary.histogram("loss_hist", losses),
            tf.summary.histogram("q_values_hist", predictions),
            tf.summary.scalar("max_q_value", tf.reduce_max(predictions))
            ])
            
            #Create summary_dir when building the model
            if summaries_dir:
                summary_dir = os.path.join(summaries_dir, "summaries_{}".format(scope))
                if not os.path.exists(summary_dir):
                    os.makedirs(summary_dir)
                summary_writer = tf.summary.FileWriter(summary_dir)

        return predictions, train_op, X_pl, y_pl, actions_pl, summaries, summary_writer, loss

# %%
def make_epsilon_greedy_policy(q_predictions, q_X, nA):
    """
    Creates an epsilon-greedy policy based on a given Q-function approximator and epsilon.
    Args:
        q_predictions: The tf node that gets q predictions for each action given a state
        q_X: The tf node that is the input placeholder for the network (state)
        nA: Number of actions in the environment.
    Returns:
        A function that takes the (sess, observation, epsilon) as an argument and returns
        the probabilities for each action in the form of a numpy array of length nA.
    """
    def policy_fn(sess, observation, epsilon):
        A = np.ones(nA, dtype=float) * epsilon / nA
        #q_values = estimator.predict(sess, np.expand_dims(observation, 0))[0]
        #Get q values for the various actions
        q_values = sess.run(q_predictions, feed_dict={q_X : np.expand_dims(observation,0)})[0]
        best_action = np.argmax(q_values)
        #Use the linearly decreasing explore factor for the suboptimal actions, and 1-epsilon for optimal
        A[best_action] += (1.0 - epsilon)
        return A
    return policy_fn

# %%
tf.reset_default_graph()
# Where we save our checkpoints and graphs
experiment_dir = os.path.relpath("./pacman_experiments")
# Create a global step variable for training iteration count
global_step = tf.Variable(0, name='global_step', trainable=False)
    

q_estimator = build_model(scope="q")
target_estimator = build_model(scope="target_q")


allrewards = []
totrewards = []
with tf.Session() as sess:
        print("SESSION STARTED")
        sess.run(tf.global_variables_initializer())
        
        latest_checkpoint = tf.train.latest_checkpoint(checkpoint_dir)
        
        new_saver = tf.train.Saver()
        new_saver.restore(sess, latest_checkpoint)
        
        q_predictions, q_train_op, q_X, q_y, q_actions, q_summaries, q_summary_writer, q_loss = q_estimator
        target_predictions, target_train_op, target_X, target_y, target_actions,\
        target_summaries, t_summary_writer, target_loss = target_estimator
        print("Loading model checkpoint {}...\n".format(latest_checkpoint))

        policy = make_epsilon_greedy_policy(
        q_predictions, q_X,
        len(poss_actions))
    
        for game in range(num_games):
            # start game 
            q_predictions, q_train_op, q_X, q_y, q_actions, q_summaries, q_summary_writer, q_loss = q_estimator
            target_predictions, target_train_op, target_X, target_y, target_actions,\
            target_summaries, t_summary_writer, target_loss = target_estimator
            state = env.reset()
            state = preprocess_observation(state)
            #Stack the initial frame 4 times initially.
            state = np.stack([state] * 4, axis=2)
            
            reward_total = 0
            while True: 
                action_probs = policy(sess, state, 0.00001)
                action = np.argmax(action_probs)
                
                new_state, reward, done, _ = env.step(action)
                allrewards.append(reward)
                next_state = preprocess_observation(new_state)
                #Stack new frame and pop out fourth frame.
                next_state = np.append(state[:,:,1:], np.expand_dims(next_state, 2), axis=2)
                
                state = next_state
                              

                if done:
                    totrewards.append(reward_total + reward)
                    print("episode " + str(game) + ": Reward = " + str(reward_total + reward))
                    with open('pacman_1000.txt', 'a') as f:
  
                        f.write(str(reward_total + reward) + "\n")
                    break
                else: 
                    # Update reward total
                    reward_total = reward_total + reward
# Out:
# WARNING:tensorflow:From <ipython-input-5-bfb4966efa56>:44: get_global_step (from tensorflow.contrib.framework.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.get_global_step
# SESSION STARTED
# INFO:tensorflow:Restoring parameters from pacman_experiments/checkpoints/model
# Loading model checkpoint pacman_experiments/checkpoints/model...
#
# episode 0: Reward = 60.0
# episode 1: Reward = 60.0
# episode 2: Reward = 60.0
# episode 3: Reward = 60.0
# episode 4: Reward = 60.0
# episode 5: Reward = 60.0
# episode 6: Reward = 60.0
# episode 7: Reward = 60.0
# episode 8: Reward = 60.0
# episode 9: Reward = 60.0
# episode 10: Reward = 60.0
# episode 11: Reward = 60.0
# episode 12: Reward = 60.0
# episode 13: Reward = 60.0
# episode 14: Reward = 60.0
# episode 15: Reward = 60.0
# episode 16: Reward = 60.0
# episode 17: Reward = 60.0
# episode 18: Reward = 60.0
# episode 19: Reward = 60.0
# episode 20: Reward = 60.0
# episode 21: Reward = 60.0
# episode 22: Reward = 60.0
# episode 23: Reward = 60.0
# episode 24: Reward = 60.0
# episode 25: Reward = 60.0
# episode 26: Reward = 60.0
# episode 27: Reward = 60.0
# episode 28: Reward = 60.0
# episode 29: Reward = 60.0
# episode 30: Reward = 60.0
# episode 31: Reward = 60.0
# episode 32: Reward = 60.0
# episode 33: Reward = 60.0
# episode 34: Reward = 60.0
# episode 35: Reward = 60.0
# episode 36: Reward = 60.0
# episode 37: Reward = 60.0
# episode 38: Reward = 60.0
# episode 39: Reward = 60.0
# episode 40: Reward = 60.0
# episode 41: Reward = 60.0
# episode 42: Reward = 60.0
# episode 43: Reward = 60.0
# episode 44: Reward = 60.0
# episode 45: Reward = 60.0
# episode 46: Reward = 60.0
# episode 47: Reward = 60.0
# episode 48: Reward = 60.0
# episode 49: Reward = 60.0
# episode 50: Reward = 60.0
# episode 51: Reward = 60.0
# episode 52: Reward = 60.0
# episode 53: Reward = 60.0
# episode 54: Reward = 60.0
# episode 55: Reward = 60.0
# episode 56: Reward = 60.0
# episode 57: Reward = 60.0
# episode 58: Reward = 60.0
# episode 59: Reward = 60.0
# episode 60: Reward = 60.0
# episode 61: Reward = 60.0
# episode 62: Reward = 60.0
# episode 63: Reward = 60.0
# episode 64: Reward = 60.0
# episode 65: Reward = 60.0
# episode 66: Reward = 60.0
# episode 67: Reward = 60.0
# episode 68: Reward = 60.0
# episode 69: Reward = 60.0
# episode 70: Reward = 60.0
# episode 71: Reward = 60.0
# episode 72: Reward = 60.0
# episode 73: Reward = 60.0
# episode 74: Reward = 60.0
# episode 75: Reward = 60.0
# episode 76: Reward = 60.0
# episode 77: Reward = 60.0
# episode 78: Reward = 60.0
# episode 79: Reward = 60.0
# episode 80: Reward = 60.0
# episode 81: Reward = 60.0
# episode 82: Reward = 60.0
# episode 83: Reward = 60.0
# episode 84: Reward = 60.0
# episode 85: Reward = 60.0
# episode 86: Reward = 60.0
# episode 87: Reward = 60.0
# episode 88: Reward = 60.0
# episode 89: Reward = 60.0
# episode 90: Reward = 60.0
# episode 91: Reward = 60.0
# episode 92: Reward = 60.0
# episode 93: Reward = 60.0
# episode 94: Reward = 60.0
# episode 95: Reward = 60.0
# episode 96: Reward = 60.0
# episode 97: Reward = 60.0
# episode 98: Reward = 60.0
# episode 99: Reward = 60.0
# episode 100: Reward = 60.0
# episode 101: Reward = 60.0
# episode 102: Reward = 60.0
# episode 103: Reward = 60.0
# episode 104: Reward = 60.0
# episode 105: Reward = 60.0
# episode 106: Reward = 60.0
# episode 107: Reward = 60.0
# episode 108: Reward = 60.0
# episode 109: Reward = 60.0
# episode 110: Reward = 60.0
# episode 111: Reward = 60.0
# episode 112: Reward = 60.0
# episode 113: Reward = 60.0
# episode 114: Reward = 60.0
# episode 115: Reward = 60.0
# episode 116: Reward = 60.0
# episode 117: Reward = 60.0
# episode 118: Reward = 60.0
# episode 119: Reward = 60.0
# episode 120: Reward = 60.0
# episode 121: Reward = 60.0
# episode 122: Reward = 60.0
# episode 123: Reward = 60.0
# episode 124: Reward = 60.0
# episode 125: Reward = 60.0
# episode 126: Reward = 60.0
# episode 127: Reward = 60.0
# episode 128: Reward = 60.0
# episode 129: Reward = 60.0
# episode 130: Reward = 60.0
# episode 131: Reward = 60.0
# episode 132: Reward = 60.0
# episode 133: Reward = 60.0
# episode 134: Reward = 60.0
# episode 135: Reward = 60.0
# episode 136: Reward = 60.0
# episode 137: Reward = 60.0
# episode 138: Reward = 60.0
# episode 139: Reward = 60.0
# episode 140: Reward = 60.0
# episode 141: Reward = 60.0
# episode 142: Reward = 60.0
# episode 143: Reward = 60.0
# episode 144: Reward = 60.0
# episode 145: Reward = 60.0
# episode 146: Reward = 60.0
# episode 147: Reward = 60.0
# episode 148: Reward = 60.0
# episode 149: Reward = 60.0
# episode 150: Reward = 60.0
# episode 151: Reward = 60.0
# episode 152: Reward = 60.0
# episode 153: Reward = 60.0
# episode 154: Reward = 60.0
# episode 155: Reward = 60.0
# episode 156: Reward = 60.0
# episode 157: Reward = 60.0
# episode 158: Reward = 60.0
# episode 159: Reward = 60.0
# episode 160: Reward = 60.0
# episode 161: Reward = 60.0
# episode 162: Reward = 60.0
# episode 163: Reward = 60.0
# episode 164: Reward = 60.0
# episode 165: Reward = 60.0
# episode 166: Reward = 60.0
# episode 167: Reward = 60.0
# episode 168: Reward = 60.0
# episode 169: Reward = 60.0
# episode 170: Reward = 60.0
# episode 171: Reward = 60.0
# episode 172: Reward = 60.0
# episode 173: Reward = 60.0
# episode 174: Reward = 60.0
# episode 175: Reward = 60.0
# episode 176: Reward = 60.0
# episode 177: Reward = 60.0
# episode 178: Reward = 60.0
# episode 179: Reward = 60.0
# episode 180: Reward = 60.0
# episode 181: Reward = 60.0
# episode 182: Reward = 60.0
# episode 183: Reward = 60.0
# episode 184: Reward = 60.0
# episode 185: Reward = 60.0
# episode 186: Reward = 60.0
# episode 187: Reward = 60.0
# episode 188: Reward = 60.0
# episode 189: Reward = 60.0
# episode 190: Reward = 60.0
# episode 191: Reward = 60.0
# episode 192: Reward = 60.0
# episode 193: Reward = 60.0
# episode 194: Reward = 60.0
# episode 195: Reward = 60.0
# episode 196: Reward = 60.0
# episode 197: Reward = 60.0
# episode 198: Reward = 60.0
# episode 199: Reward = 60.0
# episode 200: Reward = 60.0
# episode 201: Reward = 60.0
# episode 202: Reward = 60.0
# episode 203: Reward = 60.0
# episode 204: Reward = 60.0
# episode 205: Reward = 60.0
# episode 206: Reward = 60.0
# episode 207: Reward = 60.0
# episode 208: Reward = 60.0
# episode 209: Reward = 60.0
# episode 210: Reward = 60.0
# episode 211: Reward = 60.0
# episode 212: Reward = 60.0
# episode 213: Reward = 60.0
# episode 214: Reward = 60.0
# episode 215: Reward = 60.0
# episode 216: Reward = 60.0
# episode 217: Reward = 60.0
# episode 218: Reward = 60.0
# episode 219: Reward = 60.0
# episode 220: Reward = 60.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-46e8cff95581> in <module>()
#      45                 new_state, reward, done, _ = env.step(action)
#      46                 allrewards.append(reward)
# ---> 47                 next_state = preprocess_observation(new_state)
#      48                 #Stack new frame and pop out fourth frame.
#      49                 next_state = np.append(state[:,:,1:], np.expand_dims(next_state, 2), axis=2)
#
# <ipython-input-2-eab540f90011> in preprocess_observation(obs)
#       3     img = obs[1:176:2, ::2] # crop and downsize
#       4     img = img.sum(axis=2) # to greyscale
# ----> 5     img[img==mspacman_color] = 0 # Improve contrast
#       6     img = (img // 3 - 128).astype(np.int8) # normalize from -128 to 127
#       7     return img.reshape(88, 80)
#
# KeyboardInterrupt:
